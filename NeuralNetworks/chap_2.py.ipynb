# %%
import sys
sys.path.append("modules/")

import numpy as np
import pandas
import mnst_loader
import network as network_slow
import network_fast as network_fast

# %%
training_data, validation_data, test_data = mnst_loader.load_data_wrapper()

# %%
net_slow = network_slow.Network([784, 30, 10])

# %%
net_fast = network_fast.Network([784, 30, 10])

# %%
net_slow.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(101)backprop()
#     100         # feedforward
# --> 101         activation = x
#     102         activations = [x] # list to store all the activations, layer by layer
#
# ipdb> len(nabla_b)
# 2
# ipdb> len(nabla_w)
# 2
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(102)backprop()
#     101         activation = x
# --> 102         activations = [x] # list to store all the activations, layer by layer
#     103         zs = [] # list to store all the z vectors, layer by layer
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(103)backprop()
#     102         activations = [x] # list to store all the activations, layer by layer
# --> 103         zs = [] # list to store all the z vectors, layer by layer
#     104         for b, w in zip(self.biases, self.weights):
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(104)backprop()
#     103         zs = [] # list to store all the z vectors, layer by layer
# --> 104         for b, w in zip(self.biases, self.weights):
#     105             z = np.dot(w, activation)+b
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(105)backprop()
#     104         for b, w in zip(self.biases, self.weights):
# --> 105             z = np.dot(w, activation)+b
#     106             zs.append(z)
#
# ipdb> w.shape()
#   /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py(162)_run_module_as_main()
#     160         sys.argv[0] = fname
#     161     return _run_code(code, main_globals, None,
# --> 162                      "__main__", fname, loader, pkg_name)
#     163
#     164 def run_module(mod_name, init_globals=None,
#
#   /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py(72)_run_code()
#      70                        __loader__ = mod_loader,
#      71                        __package__ = pkg_name)
# ---> 72     exec code in run_globals
#      73     return run_globals
#      74
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py(3)<module>()
#       1 if __name__ == '__main__':
#       2     from ipykernel import kernelapp as app
# ----> 3     app.launch_new_instance()
#
#   /Library/Python/2.7/site-packages/traitlets/config/application.py(592)launch_instance()
#     590         app = cls.instance(**kwargs)
#     591         app.initialize(argv)
# --> 592         app.start()
#     593
#     594 #-----------------------------------------------------------------------------
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelapp.py(405)start()
#     403         self.kernel.start()
#     404         try:
# --> 405             ioloop.IOLoop.instance().start()
#     406         except KeyboardInterrupt:
#     407             pass
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/ioloop.py(162)start()
#     160     def start(self):
#     161         try:
# --> 162             super(ZMQIOLoop, self).start()
#     163         except ZMQError as e:
#     164             if e.errno == ETERM:
#
#   /usr/local/lib/python2.7/site-packages/tornado/ioloop.py(883)start()
#     881                     try:
#     882                         fd_obj, handler_func = self._handlers[fd]
# --> 883                         handler_func(fd_obj, events)
#     884                     except (OSError, IOError) as e:
#     885                         if errno_from_exception(e) == errno.EPIPE:
#
#   /usr/local/lib/python2.7/site-packages/tornado/stack_context.py(275)null_wrapper()
#     273                 current_state = _state.contexts
#     274                 _state.contexts = cap_contexts[0]
# --> 275                 return fn(*args, **kwargs)
#     276             finally:
#     277                 _state.contexts = current_state
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py(440)_handle_events()
#     438                 return
#     439             if events & IOLoop.READ:
# --> 440                 self._handle_recv()
#     441                 if not self.socket:
#     442                     return
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py(472)_handle_recv()
#     470                 callback = self._recv_callback
#     471                 # self._recv_callback = None
# --> 472                 self._run_callback(callback, msg)
#     473
#     474         # self.update_state()
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py(414)_run_callback()
#     412             # inside our blanket exception handler rather than outside.
#     413             with stack_context.NullContext():
# --> 414                 callback(*args, **kwargs)
#     415         except:
#     416             gen_log.error("Uncaught exception, closing connection.",
#
#   /usr/local/lib/python2.7/site-packages/tornado/stack_context.py(275)null_wrapper()
#     273                 current_state = _state.contexts
#     274                 _state.contexts = cap_contexts[0]
# --> 275                 return fn(*args, **kwargs)
#     276             finally:
#     277                 _state.contexts = current_state
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py(260)dispatcher()
#     258         def make_dispatcher(stream):
#     259             def dispatcher(msg):
# --> 260                 return self.dispatch_shell(stream, msg)
#     261             return dispatcher
#     262
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py(212)dispatch_shell()
#     210             self.pre_handler_hook()
#     211             try:
# --> 212                 handler(stream, idents, msg)
#     213             except Exception:
#     214                 self.log.error("Exception in message handler:", exc_info=True)
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py(370)execute_request()
#     368
#     369         reply_content = self.do_execute(code, silent, store_history,
# --> 370                                         user_expressions, allow_stdin)
#     371
#     372         # Flush output before sending the reply.
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/ipkernel.py(175)do_execute()
#     173         shell._reply_content = None
#     174         try:
# --> 175             shell.run_cell(code, store_history=store_history, silent=silent)
#     176         except:
#     177             status = u'error'
#
#   /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2902)run_cell()
#    2900                 interactivity = "none" if silent else self.ast_node_interactivity
#    2901                 self.run_ast_nodes(code_ast.body, cell_name,
# -> 2902                    interactivity=interactivity, compiler=compiler, result=result)
#    2903
#    2904                 # Reset this so later displayed values do not modify the
#
#   /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py(3012)run_ast_nodes()
#    3010                 mod = ast.Interactive([node])
#    3011                 code = compiler(mod, cell_name, "single")
# -> 3012                 if self.run_code(code, result):
#    3013                     return True
#    3014
#
#   /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py(3066)run_code()
#    3064                 self.hooks.pre_run_code_hook()
#    3065                 #rprint('Running code', repr(code_obj)) # dbg
# -> 3066                 exec(code_obj, self.user_global_ns, self.user_ns)
#    3067             finally:
#    3068                 # Reset our crash handler in place
#
#   <ipython-input-6-65b5f8286fb2>(1)<module>()
# ----> 1 net_slow.SGD(training_data, 30, 10, 3.0, test_data=test_data)
#
#   /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(62)SGD()
#      60                 for k in xrange(0, n, mini_batch_size)]
#      61             for mini_batch in mini_batches:
# ---> 62                 self.update_mini_batch(mini_batch, eta)
#      63             if test_data:
#      64                 print "Epoch {0}: {1} / {2}".format(
#
#   /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(81)update_mini_batch()
#      79         nabla_w = [np.zeros(w.shape) for w in self.weights]
#      80         for x, y in mini_batch:
# ---> 81             delta_nabla_b, delta_nabla_w = self.backprop(x, y)
#      82             nabla_b = [nb+dnb for nb, dnb in zip(nabla_b, delta_nabla_b)]
#      83             nabla_w = [nw+dnw for nw, dnw in zip(nabla_w, delta_nabla_w)]
#
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(105)backprop()
#     103         zs = [] # list to store all the z vectors, layer by layer
#     104         for b, w in zip(self.biases, self.weights):
# --> 105             z = np.dot(w, activation)+b
#     106             zs.append(z)
#     107             activation = sigmoid(z)
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(106)backprop()
#     105             z = np.dot(w, activation)+b
# --> 106             zs.append(z)
#     107             activation = sigmoid(z)
#
# ipdb> w.shape
#   /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py(162)_run_module_as_main()
#     160         sys.argv[0] = fname
#     161     return _run_code(code, main_globals, None,
# --> 162                      "__main__", fname, loader, pkg_name)
#     163
#     164 def run_module(mod_name, init_globals=None,
#
#   /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py(72)_run_code()
#      70                        __loader__ = mod_loader,
#      71                        __package__ = pkg_name)
# ---> 72     exec code in run_globals
#      73     return run_globals
#      74
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py(3)<module>()
#       1 if __name__ == '__main__':
#       2     from ipykernel import kernelapp as app
# ----> 3     app.launch_new_instance()
#
#   /Library/Python/2.7/site-packages/traitlets/config/application.py(592)launch_instance()
#     590         app = cls.instance(**kwargs)
#     591         app.initialize(argv)
# --> 592         app.start()
#     593
#     594 #-----------------------------------------------------------------------------
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelapp.py(405)start()
#     403         self.kernel.start()
#     404         try:
# --> 405             ioloop.IOLoop.instance().start()
#     406         except KeyboardInterrupt:
#     407             pass
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/ioloop.py(162)start()
#     160     def start(self):
#     161         try:
# --> 162             super(ZMQIOLoop, self).start()
#     163         except ZMQError as e:
#     164             if e.errno == ETERM:
#
#   /usr/local/lib/python2.7/site-packages/tornado/ioloop.py(883)start()
#     881                     try:
#     882                         fd_obj, handler_func = self._handlers[fd]
# --> 883                         handler_func(fd_obj, events)
#     884                     except (OSError, IOError) as e:
#     885                         if errno_from_exception(e) == errno.EPIPE:
#
#   /usr/local/lib/python2.7/site-packages/tornado/stack_context.py(275)null_wrapper()
#     273                 current_state = _state.contexts
#     274                 _state.contexts = cap_contexts[0]
# --> 275                 return fn(*args, **kwargs)
#     276             finally:
#     277                 _state.contexts = current_state
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py(440)_handle_events()
#     438                 return
#     439             if events & IOLoop.READ:
# --> 440                 self._handle_recv()
#     441                 if not self.socket:
#     442                     return
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py(472)_handle_recv()
#     470                 callback = self._recv_callback
#     471                 # self._recv_callback = None
# --> 472                 self._run_callback(callback, msg)
#     473
#     474         # self.update_state()
#
#   /usr/local/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py(414)_run_callback()
#     412             # inside our blanket exception handler rather than outside.
#     413             with stack_context.NullContext():
# --> 414                 callback(*args, **kwargs)
#     415         except:
#     416             gen_log.error("Uncaught exception, closing connection.",
#
#   /usr/local/lib/python2.7/site-packages/tornado/stack_context.py(275)null_wrapper()
#     273                 current_state = _state.contexts
#     274                 _state.contexts = cap_contexts[0]
# --> 275                 return fn(*args, **kwargs)
#     276             finally:
#     277                 _state.contexts = current_state
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py(260)dispatcher()
#     258         def make_dispatcher(stream):
#     259             def dispatcher(msg):
# --> 260                 return self.dispatch_shell(stream, msg)
#     261             return dispatcher
#     262
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py(212)dispatch_shell()
#     210             self.pre_handler_hook()
#     211             try:
# --> 212                 handler(stream, idents, msg)
#     213             except Exception:
#     214                 self.log.error("Exception in message handler:", exc_info=True)
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/kernelbase.py(370)execute_request()
#     368
#     369         reply_content = self.do_execute(code, silent, store_history,
# --> 370                                         user_expressions, allow_stdin)
#     371
#     372         # Flush output before sending the reply.
#
#   /usr/local/lib/python2.7/site-packages/ipykernel/ipkernel.py(175)do_execute()
#     173         shell._reply_content = None
#     174         try:
# --> 175             shell.run_cell(code, store_history=store_history, silent=silent)
#     176         except:
#     177             status = u'error'
#
#   /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2902)run_cell()
#    2900                 interactivity = "none" if silent else self.ast_node_interactivity
#    2901                 self.run_ast_nodes(code_ast.body, cell_name,
# -> 2902                    interactivity=interactivity, compiler=compiler, result=result)
#    2903
#    2904                 # Reset this so later displayed values do not modify the
#
#   /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py(3012)run_ast_nodes()
#    3010                 mod = ast.Interactive([node])
#    3011                 code = compiler(mod, cell_name, "single")
# -> 3012                 if self.run_code(code, result):
#    3013                     return True
#    3014
#
#   /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py(3066)run_code()
#    3064                 self.hooks.pre_run_code_hook()
#    3065                 #rprint('Running code', repr(code_obj)) # dbg
# -> 3066                 exec(code_obj, self.user_global_ns, self.user_ns)
#    3067             finally:
#    3068                 # Reset our crash handler in place
#
#   <ipython-input-6-65b5f8286fb2>(1)<module>()
# ----> 1 net_slow.SGD(training_data, 30, 10, 3.0, test_data=test_data)
#
#   /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(62)SGD()
#      60                 for k in xrange(0, n, mini_batch_size)]
#      61             for mini_batch in mini_batches:
# ---> 62                 self.update_mini_batch(mini_batch, eta)
#      63             if test_data:
#      64                 print "Epoch {0}: {1} / {2}".format(
#
#   /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(81)update_mini_batch()
#      79         nabla_w = [np.zeros(w.shape) for w in self.weights]
#      80         for x, y in mini_batch:
# ---> 81             delta_nabla_b, delta_nabla_w = self.backprop(x, y)
#      82             nabla_b = [nb+dnb for nb, dnb in zip(nabla_b, delta_nabla_b)]
#      83             nabla_w = [nw+dnw for nw, dnw in zip(nabla_w, delta_nabla_w)]
#
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(106)backprop()
#     104         for b, w in zip(self.biases, self.weights):
#     105             z = np.dot(w, activation)+b
# --> 106             zs.append(z)
#     107             activation = sigmoid(z)
#     108             activations.append(activation)
#
# ipdb> self.biases[0].shape
# (30, 1)
# ipdb> self.weights[0].shape
# (30, 784)
# ipdb> np.dot(w, activation).shape
# (30, 1)
# ipdb> activation.shape
# (784, 1)
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(107)backprop()
#     106             zs.append(z)
# --> 107             activation = sigmoid(z)
#     108             activations.append(activation)
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(108)backprop()
#     107             activation = sigmoid(z)
# --> 108             activations.append(activation)
#     109         # backward pass
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(104)backprop()
#     103         zs = [] # list to store all the z vectors, layer by layer
# --> 104         for b, w in zip(self.biases, self.weights):
#     105             z = np.dot(w, activation)+b
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(105)backprop()
#     104         for b, w in zip(self.biases, self.weights):
# --> 105             z = np.dot(w, activation)+b
#     106             zs.append(z)
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(106)backprop()
#     105             z = np.dot(w, activation)+b
# --> 106             zs.append(z)
#     107             activation = sigmoid(z)
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(107)backprop()
#     106             zs.append(z)
# --> 107             activation = sigmoid(z)
#     108             activations.append(activation)
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(108)backprop()
#     107             activation = sigmoid(z)
# --> 108             activations.append(activation)
#     109         # backward pass
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(104)backprop()
#     103         zs = [] # list to store all the z vectors, layer by layer
# --> 104         for b, w in zip(self.biases, self.weights):
#     105             z = np.dot(w, activation)+b
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(110)backprop()
#     109         # backward pass
# --> 110         delta = self.cost_derivative(activations[-1], y) * \
#     111             sigmoid_prime(zs[-1])
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(111)backprop()
#     110         delta = self.cost_derivative(activations[-1], y) * \
# --> 111             sigmoid_prime(zs[-1])
#     112         nabla_b[-1] = delta
#
# ipdb> delta
# *** NameError: name 'delta' is not defined
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(112)backprop()
#     111             sigmoid_prime(zs[-1])
# --> 112         nabla_b[-1] = delta
#     113         nabla_w[-1] = np.dot(delta, activations[-2].transpose())
#
# ipdb> delta
# array([[  1.27850655e-01],
#        [  3.45813804e-02],
#        [  1.64670968e-05],
#        [  1.29774046e-01],
#        [  3.32810695e-02],
#        [  2.08196745e-06],
#        [ -2.39670241e-03],
#        [  6.68965529e-05],
#        [  2.86172286e-02],
#        [  1.43783320e-01]])
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(113)backprop()
#     112         nabla_b[-1] = delta
# --> 113         nabla_w[-1] = np.dot(delta, activations[-2].transpose())
#     114         # Note that the variable l in the loop below is used a little
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(120)backprop()
#     119         # that Python can use negative indices in lists.
# --> 120         for l in xrange(2, self.num_layers):
#     121             z = zs[-l]
#
# ipdb> nabla_w.shape
# *** AttributeError: 'list' object has no attribute 'shape'
# ipdb> nabla_w[-1].shape
# (10, 30)
# ipdb> np.dot([1,2,3],[1,2,3].transpose())
# *** AttributeError: 'list' object has no attribute 'transpose'
# ipdb> activations[-2].transpose()
# array([[  1.45954316e-01,   1.84326162e-05,   5.76589760e-10,
#           9.81948405e-01,   3.49670302e-03,   9.99999999e-01,
#           1.42532672e-01,   9.99999934e-01,   4.60985294e-12,
#           9.99999856e-01,   1.58797650e-03,   1.66050400e-03,
#           9.99999931e-01,   9.99803697e-01,   1.38685270e-04,
#           9.56206655e-01,   9.98001819e-01,   7.39559903e-05,
#           6.95193737e-03,   6.58310587e-01,   4.06139613e-01,
#           9.99999998e-01,   9.06197981e-01,   9.93480401e-01,
#           9.99999330e-01,   3.90147093e-04,   9.98120960e-01,
#           4.15294396e-03,   9.03347459e-04,   5.84195488e-09]])
# ipdb> activations[-1]
# array([[ 0.80046575],
#        [ 0.96268589],
#        [ 0.00406624],
#        [ 0.7943153 ],
#        [ 0.96420178],
#        [ 0.00144395],
#        [ 0.94976588],
#        [ 0.00821283],
#        [ 0.18769574],
#        [ 0.59821552]])
# ipdb> activations[-2]
# array([[  1.45954316e-01],
#        [  1.84326162e-05],
#        [  5.76589760e-10],
#        [  9.81948405e-01],
#        [  3.49670302e-03],
#        [  9.99999999e-01],
#        [  1.42532672e-01],
#        [  9.99999934e-01],
#        [  4.60985294e-12],
#        [  9.99999856e-01],
#        [  1.58797650e-03],
#        [  1.66050400e-03],
#        [  9.99999931e-01],
#        [  9.99803697e-01],
#        [  1.38685270e-04],
#        [  9.56206655e-01],
#        [  9.98001819e-01],
#        [  7.39559903e-05],
#        [  6.95193737e-03],
#        [  6.58310587e-01],
#        [  4.06139613e-01],
#        [  9.99999998e-01],
#        [  9.06197981e-01],
#        [  9.93480401e-01],
#        [  9.99999330e-01],
#        [  3.90147093e-04],
#        [  9.98120960e-01],
#        [  4.15294396e-03],
#        [  9.03347459e-04],
#        [  5.84195488e-09]])
# ipdb> activations[-2].shape
# (30, 1)
# ipdb> activations[-2].transpose().shape
# (1, 30)
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(121)backprop()
#     120         for l in xrange(2, self.num_layers):
# --> 121             z = zs[-l]
#     122             sp = sigmoid_prime(z)
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(101)backprop()
#     100         # feedforward
# --> 101         activation = x
#     102         activations = [x] # list to store all the activations, layer by layer
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(102)backprop()
#     101         activation = x
# --> 102         activations = [x] # list to store all the activations, layer by layer
#     103         zs = [] # list to store all the z vectors, layer by layer
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(103)backprop()
#     102         activations = [x] # list to store all the activations, layer by layer
# --> 103         zs = [] # list to store all the z vectors, layer by layer
#     104         for b, w in zip(self.biases, self.weights):
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(104)backprop()
#     103         zs = [] # list to store all the z vectors, layer by layer
# --> 104         for b, w in zip(self.biases, self.weights):
#     105             z = np.dot(w, activation)+b
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(105)backprop()
#     104         for b, w in zip(self.biases, self.weights):
# --> 105             z = np.dot(w, activation)+b
#     106             zs.append(z)
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(106)backprop()
#     105             z = np.dot(w, activation)+b
# --> 106             zs.append(z)
#     107             activation = sigmoid(z)
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb>
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(99)backprop()
#      98         nabla_b = [np.zeros(b.shape) for b in self.biases]
# ---> 99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#     100         # feedforward
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(101)backprop()
#     100         # feedforward
# --> 101         activation = x
#     102         activations = [x] # list to store all the activations, layer by layer
#
# ipdb>
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(102)backprop()
#     101         activation = x
# --> 102         activations = [x] # list to store all the activations, layer by layer
#     103         zs = [] # list to store all the z vectors, layer by layer
#
# ipdb> n
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(103)backprop()
#     102         activations = [x] # list to store all the activations, layer by layer
# --> 103         zs = [] # list to store all the z vectors, layer by layer
#     104         for b, w in zip(self.biases, self.weights):
#
# ipdb> c
# > /Users/Loiso/Documents/PersonalProjects/PersonalStudy/NeuralNetworks/modules/network.py(98)backprop()
#      97
# ---> 98         nabla_b = [np.zeros(b.shape) for b in self.biases]
#      99         nabla_w = [np.zeros(w.shape) for w in self.weights]
#
# ipdb> exit
# Exiting Debugger.

# %%
net_fast.SGD(training_data, 30, 10, 3.0, test_data=test_data)
